# %% [markdown]
# # GRPO Training for Italian Exercise Generator
#
# Train V5 model using Group Relative Policy Optimization (GRPO) with comprehensive reward function.
#
# **Hardware**: A100 GPU (Colab Pro)
# **Expected time**: ~2-4 hours for 2000 samples

# %% [markdown]
# ## Setup

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Navigate to project
# %cd /content/drive/MyDrive/Colab\ Notebooks/italian_teacher
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/italian_teacher

# %%
# Install dependencies
# !pip install -q transformers trl accelerate peft datasets spacy sentence-transformers
# !python -m spacy download it_core_news_sm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.6/564.6 kB 36.3 MB/s eta 0:00:00
# Collecting it-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-3.8.0/it_core_news_sm-3.8.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 34.9 MB/s eta 0:00:00
# Installing collected packages: it-core-news-sm
# Successfully installed it-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('it_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import json
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from trl import GRPOConfig, GRPOTrainer
from datasets import Dataset

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.8.0+cu126
# CUDA available: True
# GPU: NVIDIA L4

# %% [markdown]
# ## Load Reward Function

# %%
from src.rl.reward_function import ExerciseRewardFunction

# Initialize reward function (loads vocabulary + models)
print("Loading reward function...")
reward_fn = ExerciseRewardFunction()
print("✅ Reward function ready")
# Out:
# Loading reward function...
# Loading spaCy model: it_core_news_sm...
# ✅ spaCy model loaded
# Initializing scorers...
# Pre-loading CEFR vocabulary (16,887 words)...
# ✅ Loaded 16887 Italian words from vocabulary list
# ✅ Loaded vocabulary for all CEFR levels
# Loading sentence transformer for topic similarity...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ Sentence transformer loaded
# ✅ Reward function initialized with all scorers
# ✅ Reward function ready

# %% [markdown]
# ## Load Training Requests

# %%
import os

# Load pre-generated training requests
if os.path.exists("src/rl/training_requests.json"):
    print("Loading existing training requests...")
    with open("src/rl/training_requests.json", "r") as f:
        training_requests = json.load(f)
else:
    # If not exists, generate them
    from src.rl.generate_training_requests import generate_training_requests
    print("Generating new training requests...")
    training_requests = generate_training_requests(
        num_requests=2000,
        output_path="src/rl/training_requests.json"
    )

print(f"✅ Loaded {len(training_requests)} training requests")
# Out:
# Loading existing training requests...
# ✅ Loaded 2000 training requests

# %% [markdown]
# ## Format Dataset

# %%
def format_prompt_with_chat_template(request: dict, tokenizer) -> str:
    """
    Format request using chat template + EXACT API prompt format.

    Combines:
    1. Llama3 chat template (required for V4)
    2. Detailed API prompt (ensures proper JSON format)
    """
    topic = request.get('topic', 'general Italian')
    grammar = request.get('grammar_focus', 'general practice')

    # Create numbered placeholders to guide the model
    exercise_numbers = ", ".join([f"#{i+1}" for i in range(request['num_exercises'])])

    topic_instruction = f"about '{topic}'"
    grammar_instruction = f"focusing on {grammar}"
    focus_text = f"{topic_instruction} {grammar_instruction}".strip()

    # Build grammar-specific instruction
    grammar_rule = ""
    if "past" in grammar.lower() or "passato" in grammar.lower():
        grammar_rule = "\n⚠️ MANDATORY: Use ONLY past tense (passato prossimo like 'ho fatto', 'sono andato' OR imperfetto like 'facevo', 'andavo'). NO present tense!"
    elif "present" in grammar.lower() or "presente" in grammar.lower():
        grammar_rule = "\n⚠️ MANDATORY: Use ONLY present tense (presente indicativo like 'faccio', 'vado'). NO past or future!"
    elif "future" in grammar.lower() or "futuro" in grammar.lower():
        grammar_rule = "\n⚠️ MANDATORY: Use ONLY future tense (futuro semplice like 'farò', 'andrò'). NO present or past!"

    # EXACT API PROMPT FORMAT - goes in user message
    user_message = f"""Create exactly {request['num_exercises']} Italian language exercises ({exercise_numbers}) in JSON format {focus_text}.

REQUIREMENTS:
Level: {request['level']}
Topic: {topic}
Grammar: {grammar}{grammar_rule}
Exercise types: {', '.join(request['exercise_types'])}

CRITICAL RULES:
1. TOPIC: Every exercise MUST be about "{topic}" - stay on topic throughout
2. REALISM: Use factual, natural scenarios appropriate for the topic
3. GRAMMAR: EVERY SINGLE exercise MUST test "{grammar}" at {request['level']} level
4. MULTIPLE CHOICE: Provide 4 DIFFERENT grammatical forms as options
5. CONSISTENCY: Do not mix different topics or introduce unrelated subjects

OUTPUT FORMAT - JSON array with exercises testing {grammar}:
[
  {{"type": "fill_in_blank", "question": "[Italian sentence about {topic} with ___ blank for {grammar}]", "correct_answer": "[conjugated form in {grammar}]", "options": null, "explanation": "[grammar rule explanation]"}},
  {{"type": "translation", "question": "Translate: [English sentence about {topic} in {grammar}]", "correct_answer": "[Italian translation using {grammar}]", "options": null, "explanation": "[grammar note]"}},
  {{"type": "multiple_choice", "question": "[Italian sentence about {topic} with blank]", "correct_answer": "[correct form in {grammar}]", "options": ["[alt1]", "[alt2]", "[alt3]", "[alt4]"], "explanation": "[why this form is correct]"}}
]

NOW GENERATE {request['num_exercises']} EXERCISES ABOUT "{topic}" TESTING "{grammar}" (remember: {grammar} ONLY!):
["""

    # Apply chat template with system + user messages
    messages = [
        {"role": "system", "content": "You are an expert Italian language teacher. Generate high-quality exercises based on the assignment specification. Output exercises in JSON format."},
        {"role": "user", "content": user_message}
    ]

    # Use tokenizer's chat template to format properly
    formatted_prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    return formatted_prompt

# %%
import random
from datasets import Dataset

# Load tokenizer first to apply chat template
from transformers import AutoTokenizer
MODEL_PATH = "/content/drive/MyDrive/Colab Notebooks/italian_teacher/models/italian_exercise_generator_v4_merged"
temp_tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)

# Create prompts WITH CHAT TEMPLATE + DETAILED INSTRUCTIONS
prompts = [format_prompt_with_chat_template(req, temp_tokenizer) for req in training_requests]

# ⚠️ PILOT RUN: Use random subset for testing
PILOT_SIZE = 400
if len(prompts) > PILOT_SIZE:
    random_indices = random.sample(range(len(prompts)), PILOT_SIZE)
    prompts = [prompts[i] for i in random_indices]
    training_requests_subset = [training_requests[i] for i in random_indices]
else:
    training_requests_subset = training_requests

# Create dataset
train_dataset = Dataset.from_dict({
    "prompt": prompts,
    "request": training_requests_subset,
})

print(f"✅ Created dataset with {len(train_dataset)} examples (PILOT RUN)")
print(f"   Using: Chat template + detailed API instructions")
print(f"\nExample prompt (first 600 chars):\n{train_dataset[0]['prompt']}...")
# Out:
# ✅ Created dataset with 400 examples (PILOT RUN)
#    Using: Chat template + detailed API instructions
#
# Example prompt (first 600 chars):
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# You are an expert Italian language teacher. Generate high-quality exercises based on the assignment specification. Output exercises in JSON format.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Create exactly 4 Italian language exercises (#1, #2, #3, #4) in JSON format about 'premiazione' focusing on prepositions.
#
# REQUIREMENTS:
# Level: C2
# Topic: premiazione
# Grammar: prepositions
# Exercise types: fill_in_blank, translation, multiple_choice
#
# CRITICAL RULES:
# 1. TOPIC: Every exercise MUST be about "premiazione" - stay on topic throughout
# 2. REALISM: Use factual, natural scenarios appropriate for the topic
# 3. GRAMMAR: EVERY SINGLE exercise MUST test "prepositions" at C2 level
# 4. MULTIPLE CHOICE: Provide 4 DIFFERENT grammatical forms as options
# 5. CONSISTENCY: Do not mix different topics or introduce unrelated subjects
#
# OUTPUT FORMAT - JSON array with exercises testing prepositions:
# [
#   {"type": "fill_in_blank", "question": "[Italian sentence about premiazione with ___ blank for prepositions]", "correct_answer": "[conjugated form in prepositions]", "options": null, "explanation": "[grammar rule explanation]"},
#   {"type": "translation", "question": "Translate: [English sentence about premiazione in prepositions]", "correct_answer": "[Italian translation using prepositions]", "options": null, "explanation": "[grammar note]"},
#   {"type": "multiple_choice", "question": "[Italian sentence about premiazione with blank]", "correct_answer": "[correct form in prepositions]", "options": ["[alt1]", "[alt2]", "[alt3]", "[alt4]"], "explanation": "[why this form is correct]"}
# ]
#
# NOW GENERATE 4 EXERCISES ABOUT "premiazione" TESTING "prepositions" (remember: prepositions ONLY!):
# [<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# ...

# %% [markdown]
# # Load YOUR V4 model - NOT a base model!
# # V4 was already trained on exercise generation, so it knows the format
# MODEL_NAME = "./models/italian_exercise_generator_v4_merged"
#
# print(f"Loading YOUR V4 model: {MODEL_NAME}")
# print("⚠️ IMPORTANT: Using V4 model that already knows exercise format!")
#
# tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
#
# # Add padding token if not present
# if tokenizer.pad_token is None:
#     tokenizer.pad_token = tokenizer.eos_token
#
# # Load model with quantization for A100
# model = AutoModelForCausalLM.from_pretrained(
#     MODEL_NAME,
#     torch_dtype=torch.bfloat16,
#     device_map="auto",
#     trust_remote_code=True
# )
#
# print("✅ V4 Model loaded - this model already generates valid exercises!")

# %%
# Use LLaMAntino-3 (Italian-optimized model) or your V4 model
MODEL_NAME = "./models/italian_v5_final"
# Alternative: "meta-llama/Llama-3.2-3B-Instruct" or your V4 model path

print(f"Loading model: {MODEL_NAME}")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# Add padding token if not present
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# Load model with quantization for A100
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    trust_remote_code=True
)

print("✅ Model loaded")
# Out:
# Loading model: ./models/italian_v5_final
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Model loaded

# %% [markdown]
# ## Define Reward Function (TRL Format)

# %%
def italian_exercise_reward(prompts=None, completions=None, completion_ids=None, **kwargs):
    """
    Reward function for Italian exercise generation.

    TRL calls this function with keyword arguments:
    - prompts: List of prompt strings
    - completions: List of generated completion strings
    - completion_ids: Token IDs of completions
    - **kwargs: All dataset columns (includes 'request')

    Returns:
        List of float rewards (0.0 to 1.0)
    """
    # Extract 'request' from kwargs (comes from dataset column)
    requests = kwargs.get('request', [])

    rewards = []

    for completion, req in zip(completions, requests):
        try:
            # Parse generated JSON
            completion_text = completion.strip()
            exercises = json.loads(completion_text)


            if not isinstance(exercises, list):
                exercises = [exercises]

            # Score each exercise with comprehensive reward function
            scores = []
            for exercise in exercises:
                score, _ = reward_fn.score(exercise, req)
                scores.append(score / 100.0)  # Normalize to 0-1

            # Average score across all exercises in the completion
            reward = sum(scores) / len(scores) if scores else 0.0

        except json.JSONDecodeError:
            # Invalid JSON - very low reward
            reward = 0.1
            print("------ invalid json -----")
            print(completion_text)
            print("-------------------------")
        except Exception as e:
            # Other errors - low reward
            reward = 0.1
        print("🎯 REWARDS:", rewards)
        rewards.append(reward)

    return rewards

print("✅ Reward function defined (TRL-compatible format)")
# Out:
# ✅ Reward function defined (TRL-compatible format)

# %% [markdown]
# # GRPO configuration - OPTIMIZED FOR PILOT RUN
# grpo_config = GRPOConfig(
#     output_dir="./models/italian_v5_grpo_pilot",
#     num_train_epochs=1,  # Reduced from 3 to 1 for pilot
#     per_device_train_batch_size=1,  # Reduced from 2 to 1 to save memory
#     gradient_accumulation_steps=4,  # Reduced from 8 to 4 (effective batch = 4)
#     learning_rate=5e-6,
#     warmup_steps=20,  # Reduced from 50
#     logging_steps=5,  # More frequent logging for pilot
#     save_steps=100,  # Save more frequently for pilot
#     save_total_limit=2,
#     bf16=True,
#     remove_unused_columns=False,
#
#     # GRPO-specific parameters - OPTIMIZED
#     num_generations=4,  # Keep 4 for GRPO algorithm
#     max_completion_length=320,  # Reduced from 512 (exercises don't need 512 tokens)
#     temperature=0.7,
#
#     # Generation optimization
#     generation_batch_size=4,  # Process generations one at a time to save memory
#
#     # CRITICAL: Add generation kwargs with stop tokens (like your API uses!)
#     generation_kwargs={
#         "do_sample": True,
#         "top_p": 0.9,
#         "eos_token_id": [128009],  # Stop token
#         "pad_token_id": 128009,
#     }
# )
#
# print("✅ GRPO config created (OPTIMIZED FOR PILOT)")
# print(f"   Added stop tokens to prevent verbose output!")
# print(f"   Estimated time: ~30-45 minutes for 200 samples")
# print(f"   Memory usage should be ~35-40GB (vs 62GB)")
# print(f"\n   For full training:")
# print(f"   - Change PILOT_SIZE to 2000 in dataset cell")
# print(f"   - Change num_train_epochs to 2-3")
# print(f"   - Consider increasing batch sizes if training succeeds")

# %%
# GRPO configuration - OPTIMIZED FOR PILOT RUN
grpo_config = GRPOConfig(
    output_dir="./models/italian_v6_grpo_pilot",
    num_train_epochs=1,  # 2-3 recommended for full dataset
    per_device_train_batch_size=1,  # Increase if memory allows
    gradient_accumulation_steps=4,  # Keeps effective batch size manageable
    learning_rate=1e-6,  # Lower than pilot to avoid forgetting
    warmup_steps=50,  # Slightly higher for longer training
    logging_steps=10,  # Less frequent logging to reduce overhead
    save_steps=100,  # Save checkpoints periodically
    save_total_limit=3,
    bf16=True,
    remove_unused_columns=False,

    # GRPO-specific parameters
    num_generations=4,
    max_completion_length=400,  # Slightly higher than pilot if needed
    temperature=0.7,

    # Generation optimization
    generation_batch_size=4,

    # Stop tokens and sampling
    generation_kwargs={
        "do_sample": True,
        "top_p": 0.9,
        "eos_token_id": [128009],
        "pad_token_id": 128009,
    }
)

print("✅ GRPO config created (OPTIMIZED FOR PILOT)")
print(f"   Estimated time: ~30-45 minutes for 200 samples")
print(f"   Memory usage should be ~35-40GB (vs 62GB)")
print(f"\n   For full training:")
print(f"   - Change PILOT_SIZE to 2000 in dataset cell")
print(f"   - Change num_train_epochs to 2-3")
print(f"   - Consider increasing batch sizes if training succeeds")
# Out:
# ✅ GRPO config created (OPTIMIZED FOR PILOT)
#    Estimated time: ~30-45 minutes for 200 samples
#    Memory usage should be ~35-40GB (vs 62GB)
#
#    For full training:
#    - Change PILOT_SIZE to 2000 in dataset cell
#    - Change num_train_epochs to 2-3
#    - Consider increasing batch sizes if training succeeds

# %% [markdown]
# ## Initialize GRPO Trainer

# %%
trainer = GRPOTrainer(
    model=model,
    args=grpo_config,  # Changed from 'config' to 'args'
    reward_funcs=italian_exercise_reward,
    train_dataset=train_dataset,
    processing_class=tokenizer,  # Changed from 'tokenizer' to 'processing_class'
)
# Out:
# The model is already on multiple devices. Skipping the move to device specified in `args`.

# %% [markdown]
# ## Start Training

# %%
print("🚀 Starting GRPO training...\n")
trainer.train()
print("\n✅ Training complete!")


output_dir = "./models/italian_v6_grpo_pilot"
trainer.save_model(output_dir)         # Saves model + adapter weights (if LoRA used)
tokenizer.save_pretrained(output_dir)  # Saves tokenizer
# Out:
# 🚀 Starting GRPO training...
# wandb: Currently logged in as: ari-katzir (ariel-katzir) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/drive/MyDrive/Colab Notebooks/italian_teacher/wandb/run-20251013_224555-4if134bm</code>
# Syncing run <strong><a href='https://wandb.ai/ariel-katzir/huggingface/runs/4if134bm' target="_blank">iconic-shadow-36</a></strong> to <a href='https://wandb.ai/ariel-katzir/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ariel-katzir/huggingface' target="_blank">https://wandb.ai/ariel-katzir/huggingface</a>
#  View run at <a href='https://wandb.ai/ariel-katzir/huggingface/runs/4if134bm' target="_blank">https://wandb.ai/ariel-katzir/huggingface/runs/4if134bm</a>
# wandb: Detected [huggingface_hub.inference, openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai/
# `generation_config` default values have been modified to match model-specific defaults: {'max_length': 8192}. If this is not desired, please set these values explicitly.
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9333333333333332]
# 🎯 REWARDS: [0.9333333333333332, 0.8433333333333334]
# 🎯 REWARDS: [0.9333333333333332, 0.8433333333333334, 0.9666666666666667]
#     <div>
#
#       <progress value='400' max='400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [400/400 1:14:10, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.010500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.027700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.007100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.009800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>-0.017000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.009200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.002300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>-0.005600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>-0.019300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.004200</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>-0.001000</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.020600</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.023000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.003000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>-0.004300</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>-0.006200</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.004800</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>-0.013600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.003400</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.013900</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>-0.002400</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.011600</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.002700</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>-0.012300</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.005700</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.023300</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>-0.002300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.014600</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.010200</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>-0.035100</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.005300</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>-0.029000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>-0.008700</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.014500</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.011700</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.009500</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.014700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.026000</td>
#     </tr>
#   </tbody>
# </table><p>
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9]
# 🎯 REWARDS: [0.9, 0.81]
# 🎯 REWARDS: [0.9, 0.81, 0.82]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.81625]
# 🎯 REWARDS: [0.81625, 0.8512500000000001]
# 🎯 REWARDS: [0.81625, 0.8512500000000001, 0.88625]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.965]
# 🎯 REWARDS: [0.965, 0.98]
# 🎯 REWARDS: [0.965, 0.98, 0.905]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9385]
# 🎯 REWARDS: [0.9385, 0.9019999999999999]
# 🎯 REWARDS: [0.9385, 0.9019999999999999, 0.9359999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.7875]
# 🎯 REWARDS: [0.7875, 0.92]
# 🎯 REWARDS: [0.7875, 0.92, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9524999999999999]
# 🎯 REWARDS: [0.9524999999999999, 0.96]
# 🎯 REWARDS: [0.9524999999999999, 0.96, 0.9299999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.984]
# 🎯 REWARDS: [0.984, 0.9189999999999999]
# 🎯 REWARDS: [0.984, 0.9189999999999999, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.92]
# 🎯 REWARDS: [0.92, 0.96]
# 🎯 REWARDS: [0.92, 0.96, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9666666666666667]
# 🎯 REWARDS: [0.9666666666666667, 0.9333333333333332]
# 🎯 REWARDS: [0.9666666666666667, 0.9333333333333332, 0.9233333333333333]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.92]
# 🎯 REWARDS: [0.96, 0.92, 0.8]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9099999999999999]
# 🎯 REWARDS: [0.9099999999999999, 0.984]
# 🎯 REWARDS: [0.9099999999999999, 0.984, 0.976]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9349999999999999]
# 🎯 REWARDS: [0.9349999999999999, 0.87]
# 🎯 REWARDS: [0.9349999999999999, 0.87, 0.8925000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.7749999999999999]
# 🎯 REWARDS: [0.7749999999999999, 0.8300000000000001]
# 🎯 REWARDS: [0.7749999999999999, 0.8300000000000001, 0.825]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9019999999999999]
# 🎯 REWARDS: [0.9019999999999999, 0.914]
# 🎯 REWARDS: [0.9019999999999999, 0.914, 0.8960000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9199999999999999]
# 🎯 REWARDS: [0.9199999999999999, 0.885]
# 🎯 REWARDS: [0.9199999999999999, 0.885, 0.915]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.83]
# 🎯 REWARDS: [0.83, 0.92]
# 🎯 REWARDS: [0.83, 0.92, 0.9450000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.7949999999999999]
# 🎯 REWARDS: [0.7949999999999999, 0.9099999999999999]
# 🎯 REWARDS: [0.7949999999999999, 0.9099999999999999, 0.8400000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.924]
# 🎯 REWARDS: [0.96, 0.924, 0.974]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9099999999999999]
# 🎯 REWARDS: [0.9099999999999999, 0.975]
# 🎯 REWARDS: [0.9099999999999999, 0.975, 0.9099999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.845]
# 🎯 REWARDS: [0.845, 0.75]
# 🎯 REWARDS: [0.845, 0.75, 0.855]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.99]
# 🎯 REWARDS: [0.96, 0.99, 0.975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.875]
# 🎯 REWARDS: [0.875, 0.88375]
# 🎯 REWARDS: [0.875, 0.88375, 0.8825]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.99]
# 🎯 REWARDS: [0.96, 0.99, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.99]
# 🎯 REWARDS: [0.96, 0.99, 0.8525]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9279999999999999]
# 🎯 REWARDS: [0.9279999999999999, 0.95]
# 🎯 REWARDS: [0.9279999999999999, 0.95, 0.9189999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.89]
# 🎯 REWARDS: [0.89, 0.8366666666666666]
# 🎯 REWARDS: [0.89, 0.8366666666666666, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9225]
# 🎯 REWARDS: [0.9225, 0.9550000000000001]
# 🎯 REWARDS: [0.9225, 0.9550000000000001, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.92]
# 🎯 REWARDS: [0.92, 0.9]
# 🎯 REWARDS: [0.92, 0.9, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.925]
# 🎯 REWARDS: [0.925, 0.9299999999999999]
# 🎯 REWARDS: [0.925, 0.9299999999999999, 0.925]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.87]
# 🎯 REWARDS: [0.94, 0.87, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.855]
# 🎯 REWARDS: [0.855, 0.8425]
# 🎯 REWARDS: [0.855, 0.8425, 0.8325]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.97]
# 🎯 REWARDS: [0.97, 0.924]
# 🎯 REWARDS: [0.97, 0.924, 0.892]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.83]
# 🎯 REWARDS: [0.83, 0.96]
# 🎯 REWARDS: [0.83, 0.96, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.86]
# 🎯 REWARDS: [0.96, 0.86, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.89]
# 🎯 REWARDS: [0.89, 0.96]
# 🎯 REWARDS: [0.89, 0.96, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9466666666666667]
# 🎯 REWARDS: [0.9466666666666667, 0.9199999999999999]
# 🎯 REWARDS: [0.9466666666666667, 0.9199999999999999, 0.9466666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9216666666666665]
# 🎯 REWARDS: [0.9216666666666665, 0.935]
# 🎯 REWARDS: [0.9216666666666665, 0.935, 0.9333333333333332]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9116666666666666]
# 🎯 REWARDS: [0.9116666666666666, 0.9899999999999999]
# 🎯 REWARDS: [0.9116666666666666, 0.9899999999999999, 0.9733333333333333]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8025]
# 🎯 REWARDS: [0.8025, 0.87]
# 🎯 REWARDS: [0.8025, 0.87, 0.9325]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9189999999999999]
# 🎯 REWARDS: [0.9189999999999999, 0.9380000000000001]
# 🎯 REWARDS: [0.9189999999999999, 0.9380000000000001, 0.9369999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.906]
# 🎯 REWARDS: [0.906, 0.9279999999999999]
# 🎯 REWARDS: [0.906, 0.9279999999999999, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.93]
# 🎯 REWARDS: [0.93, 0.85]
# 🎯 REWARDS: [0.93, 0.85, 0.77]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9566666666666667]
# 🎯 REWARDS: [0.9566666666666667, 0.7666666666666666]
# 🎯 REWARDS: [0.9566666666666667, 0.7666666666666666, 0.8466666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9]
# 🎯 REWARDS: [0.9, 0.8975]
# 🎯 REWARDS: [0.9, 0.8975, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.95]
# 🎯 REWARDS: [0.95, 0.96]
# 🎯 REWARDS: [0.95, 0.96, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.9450000000000001]
# 🎯 REWARDS: [0.96, 0.9450000000000001, 0.97]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.933]
# 🎯 REWARDS: [0.933, 0.944]
# 🎯 REWARDS: [0.933, 0.944, 0.873]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9099999999999999]
# 🎯 REWARDS: [0.9099999999999999, 0.95]
# 🎯 REWARDS: [0.9099999999999999, 0.95, 0.97]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9099999999999999]
# 🎯 REWARDS: [0.9099999999999999, 0.96]
# 🎯 REWARDS: [0.9099999999999999, 0.96, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.935]
# 🎯 REWARDS: [0.935, 0.86]
# 🎯 REWARDS: [0.935, 0.86, 0.915]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9035]
# 🎯 REWARDS: [0.9035, 0.978]
# 🎯 REWARDS: [0.9035, 0.978, 0.9719999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9533333333333333]
# 🎯 REWARDS: [0.9533333333333333, 0.9466666666666667]
# 🎯 REWARDS: [0.9533333333333333, 0.9466666666666667, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9]
# 🎯 REWARDS: [0.9, 0.9766666666666666]
# 🎯 REWARDS: [0.9, 0.9766666666666666, 0.9566666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8666666666666667]
# 🎯 REWARDS: [0.8666666666666667, 0.9700000000000001]
# 🎯 REWARDS: [0.8666666666666667, 0.9700000000000001, 0.9466666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9283333333333333]
# 🎯 REWARDS: [0.9283333333333333, 0.9583333333333334]
# 🎯 REWARDS: [0.9283333333333333, 0.9583333333333334, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.905]
# 🎯 REWARDS: [0.905, 0.81]
# 🎯 REWARDS: [0.905, 0.81, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.933]
# 🎯 REWARDS: [0.933, 0.982]
# 🎯 REWARDS: [0.933, 0.982, 0.9470000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.905]
# 🎯 REWARDS: [0.905, 0.8825000000000001]
# 🎯 REWARDS: [0.905, 0.8825000000000001, 0.9075]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.98]
# 🎯 REWARDS: [0.98, 0.8383333333333334]
# 🎯 REWARDS: [0.98, 0.8383333333333334, 0.9566666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9275]
# 🎯 REWARDS: [0.9275, 0.8975]
# 🎯 REWARDS: [0.9275, 0.8975, 0.9]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8965]
# 🎯 REWARDS: [0.8965, 0.8460000000000001]
# 🎯 REWARDS: [0.8965, 0.8460000000000001, 0.9179999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.875]
# 🎯 REWARDS: [0.875, 0.875]
# 🎯 REWARDS: [0.875, 0.875, 0.74]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.875]
# 🎯 REWARDS: [0.875, 0.9075]
# 🎯 REWARDS: [0.875, 0.9075, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.89]
# 🎯 REWARDS: [0.89, 0.91]
# 🎯 REWARDS: [0.89, 0.91, 0.9299999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.91]
# 🎯 REWARDS: [0.91, 0.92]
# 🎯 REWARDS: [0.91, 0.92, 0.9216666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.925]
# 🎯 REWARDS: [0.99, 0.925, 0.9299999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.89375]
# 🎯 REWARDS: [0.89375, 0.94]
# 🎯 REWARDS: [0.89375, 0.94, 0.9075]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.944]
# 🎯 REWARDS: [0.944, 0.8720000000000001]
# 🎯 REWARDS: [0.944, 0.8720000000000001, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.83]
# 🎯 REWARDS: [0.83, 0.77]
# 🎯 REWARDS: [0.83, 0.77, 0.9]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.5449999999999999]
# 🎯 REWARDS: [0.5449999999999999, 0.895]
# 🎯 REWARDS: [0.5449999999999999, 0.895, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9233333333333333]
# 🎯 REWARDS: [0.9233333333333333, 0.96]
# 🎯 REWARDS: [0.9233333333333333, 0.96, 0.9700000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9466666666666667]
# 🎯 REWARDS: [0.9466666666666667, 0.9666666666666667]
# 🎯 REWARDS: [0.9466666666666667, 0.9666666666666667, 0.98]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9466666666666667]
# 🎯 REWARDS: [0.9466666666666667, 0.9466666666666667]
# 🎯 REWARDS: [0.9466666666666667, 0.9466666666666667, 0.91]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9400000000000001]
# 🎯 REWARDS: [0.9400000000000001, 0.9560000000000001]
# 🎯 REWARDS: [0.9400000000000001, 0.9560000000000001, 0.9570000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.99]
# 🎯 REWARDS: [0.96, 0.99, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9025000000000001]
# 🎯 REWARDS: [0.9025000000000001, 0.9475]
# 🎯 REWARDS: [0.9025000000000001, 0.9475, 0.8625]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.83]
# 🎯 REWARDS: [0.83, 0.99]
# 🎯 REWARDS: [0.83, 0.99, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.88]
# 🎯 REWARDS: [0.96, 0.88, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.97]
# 🎯 REWARDS: [0.97, 0.96]
# 🎯 REWARDS: [0.97, 0.96, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9400000000000001]
# 🎯 REWARDS: [0.9400000000000001, 0.95]
# 🎯 REWARDS: [0.9400000000000001, 0.95, 0.9259999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9416666666666668]
# 🎯 REWARDS: [0.9416666666666668, 0.9566666666666667]
# 🎯 REWARDS: [0.9416666666666668, 0.9566666666666667, 0.8466666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.874]
# 🎯 REWARDS: [0.874, 0.966]
# 🎯 REWARDS: [0.874, 0.966, 0.924]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.92]
# 🎯 REWARDS: [0.96, 0.92, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.9025000000000001]
# 🎯 REWARDS: [0.94, 0.9025000000000001, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8775]
# 🎯 REWARDS: [0.8775, 0.94]
# 🎯 REWARDS: [0.8775, 0.94, 0.83]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.834]
# 🎯 REWARDS: [0.834, 0.9099999999999999]
# 🎯 REWARDS: [0.834, 0.9099999999999999, 0.884]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.93875]
# 🎯 REWARDS: [0.93875, 0.9225]
# 🎯 REWARDS: [0.93875, 0.9225, 0.90125]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.89]
# 🎯 REWARDS: [0.89, 0.94]
# 🎯 REWARDS: [0.89, 0.94, 0.9]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.7875]
# 🎯 REWARDS: [0.7875, 0.755]
# 🎯 REWARDS: [0.7875, 0.755, 0.825]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9475]
# 🎯 REWARDS: [0.9475, 0.915]
# 🎯 REWARDS: [0.9475, 0.915, 0.92125]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.925]
# 🎯 REWARDS: [0.96, 0.925, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.915]
# 🎯 REWARDS: [0.915, 0.84]
# 🎯 REWARDS: [0.915, 0.84, 0.915]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.85]
# 🎯 REWARDS: [0.85, 0.87125]
# 🎯 REWARDS: [0.85, 0.87125, 0.86125]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.898]
# 🎯 REWARDS: [0.898, 0.9640000000000001]
# 🎯 REWARDS: [0.898, 0.9640000000000001, 0.9105000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.92]
# 🎯 REWARDS: [0.92, 0.99]
# 🎯 REWARDS: [0.92, 0.99, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8325]
# 🎯 REWARDS: [0.8325, 0.9125]
# 🎯 REWARDS: [0.8325, 0.9125, 0.95]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8875]
# 🎯 REWARDS: [0.8875, 0.885]
# 🎯 REWARDS: [0.8875, 0.885, 0.875]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.86]
# 🎯 REWARDS: [0.86, 0.86, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.99]
# 🎯 REWARDS: [0.94, 0.99, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.88125]
# 🎯 REWARDS: [0.88125, 0.9425]
# 🎯 REWARDS: [0.88125, 0.9425, 0.77625]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.82]
# 🎯 REWARDS: [0.86, 0.82, 0.77]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.889]
# 🎯 REWARDS: [0.889, 0.901]
# 🎯 REWARDS: [0.889, 0.901, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.89]
# 🎯 REWARDS: [0.89, 0.89]
# 🎯 REWARDS: [0.89, 0.89, 0.84]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.818]
# 🎯 REWARDS: [0.818, 0.898]
# 🎯 REWARDS: [0.818, 0.898, 0.9640000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.92]
# 🎯 REWARDS: [0.99, 0.92, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8975]
# 🎯 REWARDS: [0.8975, 0.885]
# 🎯 REWARDS: [0.8975, 0.885, 0.8775000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.83]
# 🎯 REWARDS: [0.86, 0.83, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9119999999999999]
# 🎯 REWARDS: [0.9119999999999999, 0.9099999999999999]
# 🎯 REWARDS: [0.9119999999999999, 0.9099999999999999, 0.9480000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.92]
# 🎯 REWARDS: [0.92, 0.9299999999999999]
# 🎯 REWARDS: [0.92, 0.9299999999999999, 0.875]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.99]
# 🎯 REWARDS: [0.99, 0.99, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.855]
# 🎯 REWARDS: [0.855, 0.855]
# 🎯 REWARDS: [0.855, 0.855, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9675]
# 🎯 REWARDS: [0.9675, 0.975]
# 🎯 REWARDS: [0.9675, 0.975, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8933333333333334]
# 🎯 REWARDS: [0.8933333333333334, 0.9233333333333333]
# 🎯 REWARDS: [0.8933333333333334, 0.9233333333333333, 0.9466666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.92]
# 🎯 REWARDS: [0.92, 0.94]
# 🎯 REWARDS: [0.92, 0.94, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9083333333333333]
# 🎯 REWARDS: [0.9083333333333333, 0.89]
# 🎯 REWARDS: [0.9083333333333333, 0.89, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9719999999999999]
# 🎯 REWARDS: [0.9719999999999999, 0.95]
# 🎯 REWARDS: [0.9719999999999999, 0.95, 0.9359999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.7999999999999999]
# 🎯 REWARDS: [0.7999999999999999, 0.86]
# 🎯 REWARDS: [0.7999999999999999, 0.86, 0.8266666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.7925]
# 🎯 REWARDS: [0.7925, 0.87]
# 🎯 REWARDS: [0.7925, 0.87, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9733333333333333]
# 🎯 REWARDS: [0.9733333333333333, 0.9133333333333334]
# 🎯 REWARDS: [0.9733333333333333, 0.9133333333333334, 0.9700000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.9400000000000001]
# 🎯 REWARDS: [0.96, 0.9400000000000001, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.91]
# 🎯 REWARDS: [0.99, 0.91, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9425]
# 🎯 REWARDS: [0.9425, 0.9175]
# 🎯 REWARDS: [0.9425, 0.9175, 0.965]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.97]
# 🎯 REWARDS: [0.97, 0.96]
# 🎯 REWARDS: [0.97, 0.96, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9289999999999999]
# 🎯 REWARDS: [0.9289999999999999, 0.906]
# 🎯 REWARDS: [0.9289999999999999, 0.906, 0.8654999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9450000000000001]
# 🎯 REWARDS: [0.9450000000000001, 0.84]
# 🎯 REWARDS: [0.9450000000000001, 0.84, 0.95]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.92]
# 🎯 REWARDS: [0.92, 0.93]
# 🎯 REWARDS: [0.92, 0.93, 0.85]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9233333333333333]
# 🎯 REWARDS: [0.9233333333333333, 0.8866666666666667]
# 🎯 REWARDS: [0.9233333333333333, 0.8866666666666667, 0.9166666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9083333333333333]
# 🎯 REWARDS: [0.9083333333333333, 0.9133333333333334]
# 🎯 REWARDS: [0.9083333333333333, 0.9133333333333334, 0.9474999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.975]
# 🎯 REWARDS: [0.86, 0.975, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.95]
# 🎯 REWARDS: [0.95, 0.88]
# 🎯 REWARDS: [0.95, 0.88, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9325]
# 🎯 REWARDS: [0.9325, 0.89]
# 🎯 REWARDS: [0.9325, 0.89, 0.95]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9700000000000001]
# 🎯 REWARDS: [0.9700000000000001, 0.9]
# 🎯 REWARDS: [0.9700000000000001, 0.9, 0.8233333333333333]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.935]
# 🎯 REWARDS: [0.935, 0.905]
# 🎯 REWARDS: [0.935, 0.905, 0.9025000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8683333333333333]
# 🎯 REWARDS: [0.8683333333333333, 0.8566666666666666]
# 🎯 REWARDS: [0.8683333333333333, 0.8566666666666666, 0.9033333333333333]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.880625]
# 🎯 REWARDS: [0.94, 0.880625, 0.9775]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8789999999999999]
# 🎯 REWARDS: [0.8789999999999999, 0.9719999999999999]
# 🎯 REWARDS: [0.8789999999999999, 0.9719999999999999, 0.969]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.932]
# 🎯 REWARDS: [0.932, 0.9179999999999999]
# 🎯 REWARDS: [0.932, 0.9179999999999999, 0.9629999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9099999999999999]
# 🎯 REWARDS: [0.9099999999999999, 0.9490000000000001]
# 🎯 REWARDS: [0.9099999999999999, 0.9490000000000001, 0.915]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.82875]
# 🎯 REWARDS: [0.94, 0.82875, 0.8925000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9483333333333333]
# 🎯 REWARDS: [0.9483333333333333, 0.8683333333333333]
# 🎯 REWARDS: [0.9483333333333333, 0.8683333333333333, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8379999999999999]
# 🎯 REWARDS: [0.8379999999999999, 0.9339999999999999]
# 🎯 REWARDS: [0.8379999999999999, 0.9339999999999999, 0.885]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8779999999999999]
# 🎯 REWARDS: [0.8779999999999999, 0.876]
# 🎯 REWARDS: [0.8779999999999999, 0.876, 0.9339999999999999]
# 🎯 REWARDS: []
# ------ invalid json -----
# [
#   {"type": "fill_in_blank", "question": "La musica con sonorità più intense richiede un ___ volume più alto.", "correct_answer": "di", "options": null, "explanation": "Preposition 'di' is used to indicate the type of sound." },
#   {"type": "fill_in_blank", "question": "Il suono ___ strumento è più gradevole per gli orecchi.", "correct_answer": "del", "options": null, "explanation": "Preposition 'del' is used to indicate the material of something." },
#   {"type": "fill_in_blank", "question": "La sonorità ___ strada è disturbata dal traffico.", "correct_answer": "della", "options": null, "explanation": "Preposition 'della' is used to indicate the location of sound." },
#   {"type": "fill_in_blank", "question": "La tecnica per produrre suoni di alta qualità richiede ___ uso di strumenti specifici.", "correct_answer": "dell'", "options": null, "explanation": "Preposition 'dell'" is used with singular masculine nouns." },
#   {"type": "fill_in_blank", "question": "La sonorità ___ aria è cambiata dopo l'intervento di riparazione.", "correct_answer": "dell'", "options": null, "explanation": "Preposition 'dell'" is used with singular feminine nouns." }
# ]
# -------------------------
# 🎯 REWARDS: [0.952]
# 🎯 REWARDS: [0.952, 0.1]
# 🎯 REWARDS: [0.952, 0.1, 0.9719999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9675]
# 🎯 REWARDS: [0.9675, 0.89]
# 🎯 REWARDS: [0.9675, 0.89, 0.975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.92]
# 🎯 REWARDS: [0.92, 0.89]
# 🎯 REWARDS: [0.92, 0.89, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.9550000000000001]
# 🎯 REWARDS: [0.96, 0.9550000000000001, 0.9099999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.945]
# 🎯 REWARDS: [0.945, 0.835]
# 🎯 REWARDS: [0.945, 0.835, 0.825]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.925]
# 🎯 REWARDS: [0.925, 0.815]
# 🎯 REWARDS: [0.925, 0.815, 0.855]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9333333333333332]
# 🎯 REWARDS: [0.9333333333333332, 0.9233333333333333]
# 🎯 REWARDS: [0.9333333333333332, 0.9233333333333333, 0.98]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8779999999999999]
# 🎯 REWARDS: [0.8779999999999999, 0.89]
# 🎯 REWARDS: [0.8779999999999999, 0.89, 0.9259999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.95]
# 🎯 REWARDS: [0.95, 0.83]
# 🎯 REWARDS: [0.95, 0.83, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.7883333333333334]
# 🎯 REWARDS: [0.7883333333333334, 0.9233333333333333]
# 🎯 REWARDS: [0.7883333333333334, 0.9233333333333333, 0.9266666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8375]
# 🎯 REWARDS: [0.8375, 0.93]
# 🎯 REWARDS: [0.8375, 0.93, 0.9075]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.92]
# 🎯 REWARDS: [0.96, 0.92, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.952]
# 🎯 REWARDS: [0.952, 0.921]
# 🎯 REWARDS: [0.952, 0.921, 0.932]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.881]
# 🎯 REWARDS: [0.881, 0.916]
# 🎯 REWARDS: [0.881, 0.916, 0.9400000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9266666666666666]
# 🎯 REWARDS: [0.9266666666666666, 0.9500000000000001]
# 🎯 REWARDS: [0.9266666666666666, 0.9500000000000001, 0.9833333333333334]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9299999999999999]
# 🎯 REWARDS: [0.9299999999999999, 0.915]
# 🎯 REWARDS: [0.9299999999999999, 0.915, 0.975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9]
# 🎯 REWARDS: [0.9, 0.899375]
# 🎯 REWARDS: [0.9, 0.899375, 0.9575]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9333333333333332]
# 🎯 REWARDS: [0.9333333333333332, 0.9700000000000001]
# 🎯 REWARDS: [0.9333333333333332, 0.9700000000000001, 0.9466666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.97]
# 🎯 REWARDS: [0.97, 0.96]
# 🎯 REWARDS: [0.97, 0.96, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.94]
# 🎯 REWARDS: [0.94, 0.94, 0.875]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.95]
# 🎯 REWARDS: [0.95, 0.94875]
# 🎯 REWARDS: [0.95, 0.94875, 0.95]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.88]
# 🎯 REWARDS: [0.88, 0.9099999999999999]
# 🎯 REWARDS: [0.88, 0.9099999999999999, 0.925]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9425]
# 🎯 REWARDS: [0.9425, 0.9612499999999999]
# 🎯 REWARDS: [0.9425, 0.9612499999999999, 0.92625]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.865]
# 🎯 REWARDS: [0.865, 0.905]
# 🎯 REWARDS: [0.865, 0.905, 0.98]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.855]
# 🎯 REWARDS: [0.855, 0.8049999999999999]
# 🎯 REWARDS: [0.855, 0.8049999999999999, 0.725]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94875]
# 🎯 REWARDS: [0.94875, 0.94]
# 🎯 REWARDS: [0.94875, 0.94, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.935]
# 🎯 REWARDS: [0.935, 0.8925]
# 🎯 REWARDS: [0.935, 0.8925, 0.9412499999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9066666666666666]
# 🎯 REWARDS: [0.9066666666666666, 0.8566666666666666]
# 🎯 REWARDS: [0.9066666666666666, 0.8566666666666666, 0.91]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9450000000000001]
# 🎯 REWARDS: [0.9450000000000001, 0.97]
# 🎯 REWARDS: [0.9450000000000001, 0.97, 0.91]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9299999999999999]
# 🎯 REWARDS: [0.9299999999999999, 0.965]
# 🎯 REWARDS: [0.9299999999999999, 0.965, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.9199999999999999]
# 🎯 REWARDS: [0.86, 0.9199999999999999, 0.8200000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.867]
# 🎯 REWARDS: [0.867, 0.858]
# 🎯 REWARDS: [0.867, 0.858, 0.8895]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9566666666666667]
# 🎯 REWARDS: [0.9566666666666667, 0.98]
# 🎯 REWARDS: [0.9566666666666667, 0.98, 0.9133333333333334]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.965]
# 🎯 REWARDS: [0.965, 0.903125]
# 🎯 REWARDS: [0.965, 0.903125, 0.93125]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.946]
# 🎯 REWARDS: [0.946, 0.914]
# 🎯 REWARDS: [0.946, 0.914, 0.954]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.915]
# 🎯 REWARDS: [0.915, 0.91]
# 🎯 REWARDS: [0.915, 0.91, 0.9675]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.784]
# 🎯 REWARDS: [0.784, 0.78]
# 🎯 REWARDS: [0.784, 0.78, 0.798]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.95]
# 🎯 REWARDS: [0.95, 0.89]
# 🎯 REWARDS: [0.95, 0.89, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.9075]
# 🎯 REWARDS: [0.96, 0.9075, 0.9450000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.975]
# 🎯 REWARDS: [0.975, 0.935]
# 🎯 REWARDS: [0.975, 0.935, 0.9]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9075]
# 🎯 REWARDS: [0.9075, 0.915]
# 🎯 REWARDS: [0.9075, 0.915, 0.9375]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.855]
# 🎯 REWARDS: [0.855, 0.81]
# 🎯 REWARDS: [0.855, 0.81, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8875]
# 🎯 REWARDS: [0.8875, 0.88]
# 🎯 REWARDS: [0.8875, 0.88, 0.8475]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9225]
# 🎯 REWARDS: [0.9225, 0.925]
# 🎯 REWARDS: [0.9225, 0.925, 0.885]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9550000000000001]
# 🎯 REWARDS: [0.9550000000000001, 0.968]
# 🎯 REWARDS: [0.9550000000000001, 0.968, 0.946]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.97]
# 🎯 REWARDS: [0.97, 0.99]
# 🎯 REWARDS: [0.97, 0.99, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9525]
# 🎯 REWARDS: [0.9525, 0.9175]
# 🎯 REWARDS: [0.9525, 0.9175, 0.855]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.925]
# 🎯 REWARDS: [0.925, 0.9550000000000001]
# 🎯 REWARDS: [0.925, 0.9550000000000001, 0.9099999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.975]
# 🎯 REWARDS: [0.975, 0.9675]
# 🎯 REWARDS: [0.975, 0.9675, 0.975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.792]
# ------ invalid json -----
# [
#   {"type": "fill_in_blank", "question": "Mentre gli esseri umani ancora ___ cacciavano per sopravvivere, gli animali ___ erano spaventati.", "correct_answer": "cacciavano, erano", "options": null, "explanation": "Imperfect tense for actions simultaneous in the past." },
#   {"type": "fill_in_blank", "question": "Gli antichi popoli ___ descrivevano la loro cultura in pitture rupestri, mentre ___ vivevano in piccole tribù.", "correct_answer": "descrivevano, vivevano", "options": null, "explanation": "Imperfect tense for past actions, no specific time indicated." },
#   {"type": "fill_in_blank", "question": "Durante l'era glaciale, gli animali ___ migravano verso sud, mentre ___ si adattavano alle nuove condizioni.", "correct_answer": "migravano, si adattavano", "options": null, "explanation": "Imperfect tense for past actions with no specific time." },
#   {"type": "fill_in_blank", "question": "La scoperta della pietra lavorata ___ cambiò la vita delle società primitive, ___ erano in grado di creare strumenti più efficaci.", "correct_answer": "cambiò, erano", "options": null, "explanation": "Imperfect tense for a completed past action." },
#   {"type": "fill_in_blank", "question": "Gli scienziati ___ hanno scoperto che gli esseri umani ___ vivevano in piccole comunità.", "correct_answer": "hanno scoperto, vivevano", "options": null, "explanation": "Imperfect tense for past actions in a sentence with 'hanno
# -------------------------
# 🎯 REWARDS: [0.792, 0.8879999999999999]
# 🎯 REWARDS: [0.792, 0.8879999999999999, 0.1]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.93]
# 🎯 REWARDS: [0.93, 0.86]
# 🎯 REWARDS: [0.93, 0.86, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.915]
# 🎯 REWARDS: [0.99, 0.915, 0.975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.89]
# 🎯 REWARDS: [0.86, 0.89, 0.85]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9039999999999999]
# 🎯 REWARDS: [0.9039999999999999, 0.882]
# 🎯 REWARDS: [0.9039999999999999, 0.882, 0.836]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.87]
# 🎯 REWARDS: [0.87, 0.88]
# 🎯 REWARDS: [0.87, 0.88, 0.825]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.92]
# 🎯 REWARDS: [0.94, 0.92, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.875]
# 🎯 REWARDS: [0.875, 0.905]
# 🎯 REWARDS: [0.875, 0.905, 0.895]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.895]
# 🎯 REWARDS: [0.895, 0.925]
# 🎯 REWARDS: [0.895, 0.925, 0.8400000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9516666666666667]
# 🎯 REWARDS: [0.9516666666666667, 0.9783333333333334]
# 🎯 REWARDS: [0.9516666666666667, 0.9783333333333334, 0.9583333333333334]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.82]
# 🎯 REWARDS: [0.82, 0.96]
# 🎯 REWARDS: [0.82, 0.96, 0.82]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9575]
# 🎯 REWARDS: [0.9575, 0.955]
# 🎯 REWARDS: [0.9575, 0.955, 0.933125]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9375]
# 🎯 REWARDS: [0.9375, 0.8725]
# 🎯 REWARDS: [0.9375, 0.8725, 0.8674999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.976]
# 🎯 REWARDS: [0.976, 0.9259999999999999]
# 🎯 REWARDS: [0.976, 0.9259999999999999, 0.908]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.92]
# 🎯 REWARDS: [0.96, 0.92, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.99]
# 🎯 REWARDS: [0.99, 0.99, 0.87]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.955]
# 🎯 REWARDS: [0.955, 0.8624999999999999]
# 🎯 REWARDS: [0.955, 0.8624999999999999, 0.87625]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.98]
# 🎯 REWARDS: [0.98, 0.9566666666666667]
# 🎯 REWARDS: [0.98, 0.9566666666666667, 0.9566666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.97]
# 🎯 REWARDS: [0.97, 0.99]
# 🎯 REWARDS: [0.97, 0.99, 0.96]
# ------ invalid json -----
# [
#   {"type": "fill_in_blank", "question": "La finestra è bell___ per il giardino.", "correct_answer": "a", "options": null, "explanation": "Adjective agrees with 'finestra' in masculine singular form." },
#   {"type": "fill_in_blank", "question": "La finestra è grande e l'" + "___" + " è piccola.", "correct_answer": "finestra", "options": null, "explanation": "Adjective agrees with 'finestra' in feminine singular form." },
#   {"type": "fill_in_blank", "question": "La finestra è brut___, non funziona più.", "correct_answer": "a", "options": null, "explanation": "Adjective agrees with 'finestra' in masculine singular form." }
# ]
# -------------------------
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.1]
# 🎯 REWARDS: [0.1, 0.88]
# 🎯 REWARDS: [0.1, 0.88, 0.9066666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9109999999999999]
# 🎯 REWARDS: [0.9109999999999999, 0.9369999999999999]
# 🎯 REWARDS: [0.9109999999999999, 0.9369999999999999, 0.9039999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.984]
# 🎯 REWARDS: [0.984, 0.9719999999999999]
# 🎯 REWARDS: [0.984, 0.9719999999999999, 0.974]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.99]
# 🎯 REWARDS: [0.99, 0.99, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.97]
# 🎯 REWARDS: [0.97, 0.97]
# 🎯 REWARDS: [0.97, 0.97, 0.9039999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.975]
# 🎯 REWARDS: [0.975, 0.9824999999999999]
# 🎯 REWARDS: [0.975, 0.9824999999999999, 0.97]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.99]
# 🎯 REWARDS: [0.86, 0.99, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86375]
# 🎯 REWARDS: [0.86375, 0.905]
# 🎯 REWARDS: [0.86375, 0.905, 0.8975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.93]
# 🎯 REWARDS: [0.93, 0.97]
# 🎯 REWARDS: [0.93, 0.97, 0.82]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.91]
# 🎯 REWARDS: [0.91, 0.8999999999999999]
# 🎯 REWARDS: [0.91, 0.8999999999999999, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8875]
# 🎯 REWARDS: [0.8875, 0.9475]
# 🎯 REWARDS: [0.8875, 0.9475, 0.9475]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9]
# 🎯 REWARDS: [0.9, 0.71]
# 🎯 REWARDS: [0.9, 0.71, 0.88]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9225]
# 🎯 REWARDS: [0.9225, 0.915]
# 🎯 REWARDS: [0.9225, 0.915, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.966]
# 🎯 REWARDS: [0.966, 0.978]
# 🎯 REWARDS: [0.966, 0.978, 0.9560000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.968]
# 🎯 REWARDS: [0.968, 0.9]
# 🎯 REWARDS: [0.968, 0.9, 0.932]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.99]
# 🎯 REWARDS: [0.96, 0.99, 0.79]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.749]
# 🎯 REWARDS: [0.749, 0.749]
# 🎯 REWARDS: [0.749, 0.749, 0.9119999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9075]
# 🎯 REWARDS: [0.9075, 0.8674999999999999]
# 🎯 REWARDS: [0.9075, 0.8674999999999999, 0.9550000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.925]
# 🎯 REWARDS: [0.99, 0.925, 0.97]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8300000000000001]
# 🎯 REWARDS: [0.8300000000000001, 0.91]
# 🎯 REWARDS: [0.8300000000000001, 0.91, 0.9166666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9333333333333332]
# 🎯 REWARDS: [0.9333333333333332, 0.8566666666666666]
# 🎯 REWARDS: [0.9333333333333332, 0.8566666666666666, 0.9400000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.93125]
# 🎯 REWARDS: [0.86, 0.93125, 0.915]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.87]
# 🎯 REWARDS: [0.87, 0.89]
# 🎯 REWARDS: [0.87, 0.89, 0.895]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8433333333333333]
# 🎯 REWARDS: [0.8433333333333333, 0.9333333333333332]
# 🎯 REWARDS: [0.8433333333333333, 0.9333333333333332, 0.9700000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.806]
# 🎯 REWARDS: [0.806, 0.826]
# 🎯 REWARDS: [0.806, 0.826, 0.8699999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9425]
# 🎯 REWARDS: [0.9425, 0.915]
# 🎯 REWARDS: [0.9425, 0.915, 0.8825]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.876]
# 🎯 REWARDS: [0.876, 0.9199999999999999]
# 🎯 REWARDS: [0.876, 0.9199999999999999, 0.9339999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.975]
# 🎯 REWARDS: [0.975, 0.99]
# 🎯 REWARDS: [0.975, 0.99, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.89]
# 🎯 REWARDS: [0.89, 0.8799999999999999]
# 🎯 REWARDS: [0.89, 0.8799999999999999, 0.98]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.97]
# 🎯 REWARDS: [0.96, 0.97, 0.825]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8275]
# 🎯 REWARDS: [0.8275, 0.915]
# 🎯 REWARDS: [0.8275, 0.915, 0.865]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9039999999999999]
# 🎯 REWARDS: [0.9039999999999999, 0.884]
# 🎯 REWARDS: [0.9039999999999999, 0.884, 0.9730000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8320000000000001]
# 🎯 REWARDS: [0.8320000000000001, 0.966]
# 🎯 REWARDS: [0.8320000000000001, 0.966, 0.914]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.87]
# 🎯 REWARDS: [0.99, 0.87, 0.88]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9475]
# 🎯 REWARDS: [0.9475, 0.9575]
# 🎯 REWARDS: [0.9475, 0.9575, 0.9775]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.87]
# 🎯 REWARDS: [0.87, 0.9]
# 🎯 REWARDS: [0.87, 0.9, 0.8766666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.8933333333333332]
# 🎯 REWARDS: [0.96, 0.8933333333333332, 0.8416666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9116666666666666]
# 🎯 REWARDS: [0.9116666666666666, 0.9566666666666667]
# 🎯 REWARDS: [0.9116666666666666, 0.9566666666666667, 0.9833333333333334]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8333333333333334]
# 🎯 REWARDS: [0.8333333333333334, 0.9199999999999999]
# 🎯 REWARDS: [0.8333333333333334, 0.9199999999999999, 0.8766666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9700000000000001]
# 🎯 REWARDS: [0.9700000000000001, 0.835]
# 🎯 REWARDS: [0.9700000000000001, 0.835, 0.935]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9550000000000001]
# 🎯 REWARDS: [0.9550000000000001, 0.96]
# 🎯 REWARDS: [0.9550000000000001, 0.96, 0.925]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9233333333333333]
# 🎯 REWARDS: [0.9233333333333333, 0.8433333333333333]
# 🎯 REWARDS: [0.9233333333333333, 0.8433333333333333, 0.9316666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9033333333333333]
# 🎯 REWARDS: [0.9033333333333333, 0.9066666666666666]
# 🎯 REWARDS: [0.9033333333333333, 0.9066666666666666, 0.7833333333333333]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.93]
# 🎯 REWARDS: [0.93, 0.99]
# 🎯 REWARDS: [0.93, 0.99, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.892]
# 🎯 REWARDS: [0.892, 0.909]
# 🎯 REWARDS: [0.892, 0.909, 0.8310000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.915]
# 🎯 REWARDS: [0.94, 0.915, 0.935]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.965]
# 🎯 REWARDS: [0.965, 0.9199999999999999]
# 🎯 REWARDS: [0.965, 0.9199999999999999, 0.8075]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.85]
# 🎯 REWARDS: [0.96, 0.85, 0.8]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.925]
# 🎯 REWARDS: [0.925, 0.9199999999999999]
# 🎯 REWARDS: [0.925, 0.9199999999999999, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9325]
# 🎯 REWARDS: [0.9325, 0.9475]
# 🎯 REWARDS: [0.9325, 0.9475, 0.9675]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9575]
# 🎯 REWARDS: [0.9575, 0.965]
# 🎯 REWARDS: [0.9575, 0.965, 0.975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8960000000000001]
# 🎯 REWARDS: [0.8960000000000001, 0.898]
# 🎯 REWARDS: [0.8960000000000001, 0.898, 0.906]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.92]
# 🎯 REWARDS: [0.92, 0.96]
# 🎯 REWARDS: [0.92, 0.96, 0.97]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.8899999999999999]
# 🎯 REWARDS: [0.94, 0.8899999999999999, 0.84125]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9199999999999999]
# 🎯 REWARDS: [0.9199999999999999, 0.9400000000000001]
# 🎯 REWARDS: [0.9199999999999999, 0.9400000000000001, 0.9460000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.96]
# 🎯 REWARDS: [0.94, 0.96, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.96]
# 🎯 REWARDS: [0.99, 0.96, 0.79]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.932]
# 🎯 REWARDS: [0.932, 0.95]
# 🎯 REWARDS: [0.932, 0.95, 0.938]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8240000000000001]
# 🎯 REWARDS: [0.8240000000000001, 0.874]
# 🎯 REWARDS: [0.8240000000000001, 0.874, 0.898]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.87]
# 🎯 REWARDS: [0.87, 0.945]
# 🎯 REWARDS: [0.87, 0.945, 0.965]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.98]
# 🎯 REWARDS: [0.98, 0.9550000000000001]
# 🎯 REWARDS: [0.98, 0.9550000000000001, 0.925]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.925]
# 🎯 REWARDS: [0.925, 0.99]
# 🎯 REWARDS: [0.925, 0.99, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.905]
# 🎯 REWARDS: [0.905, 0.99]
# 🎯 REWARDS: [0.905, 0.99, 0.9675]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.87]
# 🎯 REWARDS: [0.87, 0.96]
# 🎯 REWARDS: [0.87, 0.96, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.83]
# 🎯 REWARDS: [0.83, 0.99]
# 🎯 REWARDS: [0.83, 0.99, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8899999999999999]
# 🎯 REWARDS: [0.8899999999999999, 0.8899999999999999]
# 🎯 REWARDS: [0.8899999999999999, 0.8899999999999999, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9325]
# 🎯 REWARDS: [0.9325, 0.945]
# 🎯 REWARDS: [0.9325, 0.945, 0.9562499999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.928125]
# 🎯 REWARDS: [0.928125, 0.905]
# 🎯 REWARDS: [0.928125, 0.905, 0.93125]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.89]
# 🎯 REWARDS: [0.89, 0.806]
# 🎯 REWARDS: [0.89, 0.806, 0.868]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9325]
# 🎯 REWARDS: [0.9325, 0.9349999999999999]
# 🎯 REWARDS: [0.9325, 0.9349999999999999, 0.91]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.99]
# 🎯 REWARDS: [0.86, 0.99, 0.82]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.827]
# 🎯 REWARDS: [0.827, 0.9]
# 🎯 REWARDS: [0.827, 0.9, 0.796]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.94]
# 🎯 REWARDS: [0.99, 0.94, 0.975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.975]
# 🎯 REWARDS: [0.99, 0.975, 0.9099999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.91]
# 🎯 REWARDS: [0.91, 0.82]
# 🎯 REWARDS: [0.91, 0.82, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9233333333333333]
# 🎯 REWARDS: [0.9233333333333333, 0.9700000000000001]
# 🎯 REWARDS: [0.9233333333333333, 0.9700000000000001, 0.9366666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9525]
# 🎯 REWARDS: [0.9525, 0.9550000000000001]
# 🎯 REWARDS: [0.9525, 0.9550000000000001, 0.9475]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9466666666666667]
# 🎯 REWARDS: [0.9466666666666667, 0.9700000000000001]
# 🎯 REWARDS: [0.9466666666666667, 0.9700000000000001, 0.9066666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.935]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.898]
# 🎯 REWARDS: [0.898, 0.866]
# 🎯 REWARDS: [0.898, 0.866, 0.9039999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.82]
# 🎯 REWARDS: [0.82, 0.92]
# 🎯 REWARDS: [0.82, 0.92, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.85]
# 🎯 REWARDS: [0.85, 0.882]
# 🎯 REWARDS: [0.85, 0.882, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.9725]
# 🎯 REWARDS: [0.96, 0.9725, 0.946875]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9339999999999999]
# 🎯 REWARDS: [0.9339999999999999, 0.914]
# 🎯 REWARDS: [0.9339999999999999, 0.914, 0.8779999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8960000000000001]
# 🎯 REWARDS: [0.8960000000000001, 0.908]
# 🎯 REWARDS: [0.8960000000000001, 0.908, 0.9359999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9500000000000001]
# 🎯 REWARDS: [0.9500000000000001, 0.7366666666666667]
# 🎯 REWARDS: [0.9500000000000001, 0.7366666666666667, 0.9199999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.9033333333333333]
# 🎯 REWARDS: [0.94, 0.9033333333333333, 0.955]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9724999999999999]
# 🎯 REWARDS: [0.9724999999999999, 0.9349999999999999]
# 🎯 REWARDS: [0.9724999999999999, 0.9349999999999999, 0.8775]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8625]
# 🎯 REWARDS: [0.8625, 0.925]
# 🎯 REWARDS: [0.8625, 0.925, 0.885]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.95]
# 🎯 REWARDS: [0.95, 0.9480000000000001]
# 🎯 REWARDS: [0.95, 0.9480000000000001, 0.9380000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.96]
# 🎯 REWARDS: [0.99, 0.96, 0.9575]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.94]
# 🎯 REWARDS: [0.96, 0.94, 0.95]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9175]
# 🎯 REWARDS: [0.9175, 0.9]
# 🎯 REWARDS: [0.9175, 0.9, 0.915]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94875]
# 🎯 REWARDS: [0.94875, 0.95]
# 🎯 REWARDS: [0.94875, 0.95, 0.9425]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.7849999999999999]
# 🎯 REWARDS: [0.7849999999999999, 0.9099999999999999]
# 🎯 REWARDS: [0.7849999999999999, 0.9099999999999999, 0.87]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.915]
# 🎯 REWARDS: [0.915, 0.89]
# 🎯 REWARDS: [0.915, 0.89, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8933333333333334]
# 🎯 REWARDS: [0.8933333333333334, 0.9666666666666667]
# 🎯 REWARDS: [0.8933333333333334, 0.9666666666666667, 0.9233333333333333]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.96]
# 🎯 REWARDS: [0.86, 0.96, 0.925]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.99]
# 🎯 REWARDS: [0.96, 0.99, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.83]
# 🎯 REWARDS: [0.83, 0.93]
# 🎯 REWARDS: [0.83, 0.93, 0.93]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.975]
# 🎯 REWARDS: [0.975, 0.9475]
# 🎯 REWARDS: [0.975, 0.9475, 0.9512499999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.876]
# 🎯 REWARDS: [0.876, 0.866]
# 🎯 REWARDS: [0.876, 0.866, 0.9279999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9666666666666667]
# 🎯 REWARDS: [0.9666666666666667, 0.98]
# 🎯 REWARDS: [0.9666666666666667, 0.98, 0.9525]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.915]
# 🎯 REWARDS: [0.915, 0.96]
# 🎯 REWARDS: [0.915, 0.96, 0.875]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.955625]
# 🎯 REWARDS: [0.955625, 0.965]
# 🎯 REWARDS: [0.955625, 0.965, 0.86375]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8899999999999999]
# 🎯 REWARDS: [0.8899999999999999, 0.8049999999999999]
# 🎯 REWARDS: [0.8899999999999999, 0.8049999999999999, 0.8400000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.865]
# 🎯 REWARDS: [0.865, 0.855]
# 🎯 REWARDS: [0.865, 0.855, 0.825]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.83]
# 🎯 REWARDS: [0.83, 0.91]
# 🎯 REWARDS: [0.83, 0.91, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9]
# 🎯 REWARDS: [0.9, 0.8666666666666667]
# 🎯 REWARDS: [0.9, 0.8666666666666667, 0.8624999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9733333333333333]
# 🎯 REWARDS: [0.9733333333333333, 0.8649999999999999]
# 🎯 REWARDS: [0.9733333333333333, 0.8649999999999999, 0.9116666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9233333333333333]
# 🎯 REWARDS: [0.9233333333333333, 0.89]
# 🎯 REWARDS: [0.9233333333333333, 0.89, 0.9249999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9400000000000001]
# 🎯 REWARDS: [0.9400000000000001, 0.9480000000000001]
# 🎯 REWARDS: [0.9400000000000001, 0.9480000000000001, 0.9460000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9525]
# 🎯 REWARDS: [0.9525, 0.94]
# 🎯 REWARDS: [0.9525, 0.94, 0.9199999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94375]
# 🎯 REWARDS: [0.94375, 0.90625]
# 🎯 REWARDS: [0.94375, 0.90625, 0.9575]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.9]
# 🎯 REWARDS: [0.99, 0.9, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.99]
# 🎯 REWARDS: [0.99, 0.99, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.9099999999999999]
# 🎯 REWARDS: [0.94, 0.9099999999999999, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.975]
# 🎯 REWARDS: [0.975, 0.9212499999999999]
# 🎯 REWARDS: [0.975, 0.9212499999999999, 0.9299999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.975]
# 🎯 REWARDS: [0.94, 0.975, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9466666666666667]
# 🎯 REWARDS: [0.9466666666666667, 0.8666666666666667]
# 🎯 REWARDS: [0.9466666666666667, 0.8666666666666667, 0.8866666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.978]
# 🎯 REWARDS: [0.978, 0.8879999999999999]
# 🎯 REWARDS: [0.978, 0.8879999999999999, 0.9359999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.85]
# 🎯 REWARDS: [0.86, 0.85, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9019999999999999]
# 🎯 REWARDS: [0.9019999999999999, 0.8709999999999999]
# 🎯 REWARDS: [0.9019999999999999, 0.8709999999999999, 0.8939999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8333333333333334]
# 🎯 REWARDS: [0.8333333333333334, 0.79]
# 🎯 REWARDS: [0.8333333333333334, 0.79, 0.8133333333333334]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.865]
# 🎯 REWARDS: [0.94, 0.865, 0.975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9275]
# 🎯 REWARDS: [0.9275, 0.9249999999999999]
# 🎯 REWARDS: [0.9275, 0.9249999999999999, 0.865]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9299999999999999]
# 🎯 REWARDS: [0.9299999999999999, 0.9550000000000001]
# 🎯 REWARDS: [0.9299999999999999, 0.9550000000000001, 0.98]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.99]
# 🎯 REWARDS: [0.96, 0.99, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9039999999999999]
# 🎯 REWARDS: [0.9039999999999999, 0.932]
# 🎯 REWARDS: [0.9039999999999999, 0.932, 0.944]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9640000000000001]
# 🎯 REWARDS: [0.9640000000000001, 0.916]
# 🎯 REWARDS: [0.9640000000000001, 0.916, 0.9460000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.876]
# 🎯 REWARDS: [0.876, 0.89]
# 🎯 REWARDS: [0.876, 0.89, 0.9560000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.975]
# 🎯 REWARDS: [0.975, 0.895]
# 🎯 REWARDS: [0.975, 0.895, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.925]
# 🎯 REWARDS: [0.925, 0.925]
# 🎯 REWARDS: [0.925, 0.925, 0.905]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.935]
# 🎯 REWARDS: [0.935, 0.9575]
# 🎯 REWARDS: [0.935, 0.9575, 0.9575]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.88]
# 🎯 REWARDS: [0.99, 0.88, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.89]
# 🎯 REWARDS: [0.89, 0.8899999999999999]
# 🎯 REWARDS: [0.89, 0.8899999999999999, 0.87]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.855]
# 🎯 REWARDS: [0.855, 0.975]
# 🎯 REWARDS: [0.855, 0.975, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.8400000000000001]
# 🎯 REWARDS: [0.94, 0.8400000000000001, 0.92]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8833333333333333]
# 🎯 REWARDS: [0.8833333333333333, 0.8333333333333334]
# 🎯 REWARDS: [0.8833333333333333, 0.8333333333333334, 0.8233333333333333]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.98]
# 🎯 REWARDS: [0.96, 0.98, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9033333333333333]
# 🎯 REWARDS: [0.9033333333333333, 0.9]
# 🎯 REWARDS: [0.9033333333333333, 0.9, 0.9233333333333333]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.945]
# 🎯 REWARDS: [0.96, 0.945, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.665]
# 🎯 REWARDS: [0.665, 0.86]
# 🎯 REWARDS: [0.665, 0.86, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9179999999999999]
# 🎯 REWARDS: [0.9179999999999999, 0.914]
# 🎯 REWARDS: [0.9179999999999999, 0.914, 0.916]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9475]
# 🎯 REWARDS: [0.9475, 0.8975]
# 🎯 REWARDS: [0.9475, 0.8975, 0.9575]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.82]
# 🎯 REWARDS: [0.82, 0.86]
# 🎯 REWARDS: [0.82, 0.86, 0.8633333333333333]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9075]
# 🎯 REWARDS: [0.9075, 0.90125]
# 🎯 REWARDS: [0.9075, 0.90125, 0.885]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9475]
# 🎯 REWARDS: [0.9475, 0.9425]
# 🎯 REWARDS: [0.9475, 0.9425, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.93]
# 🎯 REWARDS: [0.93, 0.8525]
# 🎯 REWARDS: [0.93, 0.8525, 0.84]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9475]
# 🎯 REWARDS: [0.9475, 0.94]
# 🎯 REWARDS: [0.9475, 0.94, 0.975]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.95]
# 🎯 REWARDS: [0.95, 0.93]
# 🎯 REWARDS: [0.95, 0.93, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.975]
# 🎯 REWARDS: [0.96, 0.975, 0.91]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.8666666666666667]
# 🎯 REWARDS: [0.86, 0.8666666666666667, 0.8366666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8800000000000001]
# 🎯 REWARDS: [0.8800000000000001, 0.93]
# 🎯 REWARDS: [0.8800000000000001, 0.93, 0.923]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9199999999999999]
# 🎯 REWARDS: [0.9199999999999999, 0.9233333333333333]
# 🎯 REWARDS: [0.9199999999999999, 0.9233333333333333, 0.85]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9575]
# 🎯 REWARDS: [0.9575, 0.86]
# 🎯 REWARDS: [0.9575, 0.86, 0.94]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9633333333333333]
# 🎯 REWARDS: [0.9633333333333333, 0.9133333333333334]
# 🎯 REWARDS: [0.9633333333333333, 0.9133333333333334, 0.9500000000000001]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.908]
# 🎯 REWARDS: [0.908, 0.898]
# 🎯 REWARDS: [0.908, 0.898, 0.9279999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.86]
# 🎯 REWARDS: [0.86, 0.99]
# 🎯 REWARDS: [0.86, 0.99, 0.99]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9525]
# 🎯 REWARDS: [0.9525, 0.9575]
# 🎯 REWARDS: [0.9525, 0.9575, 0.9375]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.91]
# 🎯 REWARDS: [0.91, 0.9500000000000001]
# 🎯 REWARDS: [0.91, 0.9500000000000001, 0.9666666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8233333333333333]
# 🎯 REWARDS: [0.8233333333333333, 0.8666666666666667]
# 🎯 REWARDS: [0.8233333333333333, 0.8666666666666667, 0.8466666666666667]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8866666666666667]
# 🎯 REWARDS: [0.8866666666666667, 0.8933333333333334]
# 🎯 REWARDS: [0.8866666666666667, 0.8933333333333334, 0.7999999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.909]
# 🎯 REWARDS: [0.909, 0.9400000000000001]
# 🎯 REWARDS: [0.909, 0.9400000000000001, 0.933]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.825]
# 🎯 REWARDS: [0.825, 0.8525]
# 🎯 REWARDS: [0.825, 0.8525, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.8699999999999999]
# 🎯 REWARDS: [0.8699999999999999, 0.8939999999999999]
# 🎯 REWARDS: [0.8699999999999999, 0.8939999999999999, 0.9199999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.82]
# 🎯 REWARDS: [0.82, 0.87]
# 🎯 REWARDS: [0.82, 0.87, 0.97]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.94]
# 🎯 REWARDS: [0.94, 0.9550000000000001]
# 🎯 REWARDS: [0.94, 0.9550000000000001, 0.8574999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.875]
# 🎯 REWARDS: [0.875, 0.96]
# 🎯 REWARDS: [0.875, 0.96, 0.8574999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9525]
# 🎯 REWARDS: [0.9525, 0.95]
# 🎯 REWARDS: [0.9525, 0.95, 0.984]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.938]
# 🎯 REWARDS: [0.938, 0.9640000000000001]
# 🎯 REWARDS: [0.938, 0.9640000000000001, 0.9189999999999999]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.96]
# 🎯 REWARDS: [0.96, 0.96]
# 🎯 REWARDS: [0.96, 0.96, 0.86]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.876]
# 🎯 REWARDS: [0.876, 0.8800000000000001]
# 🎯 REWARDS: [0.876, 0.8800000000000001, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.99]
# 🎯 REWARDS: [0.99, 0.93]
# 🎯 REWARDS: [0.99, 0.93, 0.96]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9279999999999999]
# 🎯 REWARDS: [0.9279999999999999, 0.9179999999999999]
# 🎯 REWARDS: [0.9279999999999999, 0.9179999999999999, 0.925]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.9366666666666666]
# 🎯 REWARDS: [0.9366666666666666, 0.9166666666666666]
# 🎯 REWARDS: [0.9366666666666666, 0.9166666666666666, 0.9366666666666666]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.88]
# 🎯 REWARDS: [0.88, 0.86]
# 🎯 REWARDS: [0.88, 0.86, 0.89]
# 🎯 REWARDS: []
# 🎯 REWARDS: [0.975]
# 🎯 REWARDS: [0.975, 0.985]
# 🎯 REWARDS: [0.975, 0.985, 0.9216666666666665]
#
# ✅ Training complete!
# ('./models/italian_v6_grpo_pilot/tokenizer_config.json',
#  './models/italian_v6_grpo_pilot/special_tokens_map.json',
#  './models/italian_v6_grpo_pilot/chat_template.jinja',
#  './models/italian_v6_grpo_pilot/tokenizer.json')

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("./models/italian_v6_grpo_pilot/checkpoint-400")
tokenizer = AutoTokenizer.from_pretrained("./models/italian_v6_grpo_pilot/checkpoint-400")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
import re
import json

# ========== 1️⃣ TEST REQUEST ==========
test_request = {
    "level": "A1",
    "grammar_focus": "past_tense",
    "topic": "buttons",
    "num_exercises": 2,
    "exercise_types": ["translation", "fill_in_blank"]
}

# ========== 2️⃣ FORMAT PROMPT ==========
test_prompt = format_prompt_with_chat_template(test_request, tokenizer)
print(f"PROMPT SENT TO MODEL:\n{test_prompt}\n")

inputs = tokenizer(test_prompt, return_tensors="pt").to(model.device)

# ========== 3️⃣ GENERATE ==========
outputs = model.generate(
    **inputs,
    max_new_tokens=400,
    temperature=0.7,
    do_sample=True,
    top_p=0.9,
    eos_token_id=128009,  # IMPORTANT: Same as training
    pad_token_id=128009
)

generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()
print("🔍 FULL RAW MODEL OUTPUT:")
print(generated_text)
print("--------------------------------------------------")

# ========== 4️⃣ CLEAN & EXTRACT JSON ONLY ==========
# Use REGEX to extract ONLY the FIRST valid JSON array
matches = re.findall(r"\[\s*{.*?}\s*\]", generated_text, re.DOTALL)
if not matches:
    raise ValueError("❌ No valid JSON array found in output!")
json_text = matches[-1]  # Use the LAST block (real output)

if not matches:
    raise ValueError("❌ No valid JSON array found in output!")

print("✅ CLEANED JSON BLOCK EXTRACTED:")
print(json_text)
print("--------------------------------------------------")

# ========== 5️⃣ PARSE JSON SAFELY ==========
try:
    exercises = json.loads(json_text)
except json.JSONDecodeError as e:
    raise ValueError(f"❌ JSON parsing error: {e}")

if not isinstance(exercises, list):
    exercises = [exercises]

print(f"🎯 SUCCESS: Parsed {len(exercises)} exercises!")
print("--------------------------------------------------")

# ========== 6️⃣ SCORE OUTPUT ==========
for i, ex in enumerate(exercises):
    score, breakdown = reward_fn.score(ex, test_request)
    print(f"\n{'='*60}")
    print(f"📝 Exercise {i+1} Score: {score}/100")
    print(f"{'='*60}")
    print(f"Type: {ex.get('type')}")
    print(f"Question: {ex.get('question')}")
    print(f"Answer: {ex.get('correct_answer')}")
    if ex.get('options'):
        print(f"Options: {ex.get('options')}")
    print(f"\nDetails: {breakdown}")
# Out:
# PROMPT SENT TO MODEL:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# You are an expert Italian language teacher. Generate high-quality exercises based on the assignment specification. Output exercises in JSON format.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Create exactly 2 Italian language exercises (#1, #2) in JSON format about 'buttons' focusing on past_tense.
#
# REQUIREMENTS:
# Level: A1
# Topic: buttons
# Grammar: past_tense
# ⚠️ MANDATORY: Use ONLY past tense (passato prossimo like 'ho fatto', 'sono andato' OR imperfetto like 'facevo', 'andavo'). NO present tense!
# Exercise types: translation, fill_in_blank
#
# CRITICAL RULES:
# 1. TOPIC: Every exercise MUST be about "buttons" - stay on topic throughout
# 2. REALISM: Use factual, natural scenarios appropriate for the topic
# 3. GRAMMAR: EVERY SINGLE exercise MUST test "past_tense" at A1 level
# 4. MULTIPLE CHOICE: Provide 4 DIFFERENT grammatical forms as options
# 5. CONSISTENCY: Do not mix different topics or introduce unrelated subjects
#
# OUTPUT FORMAT - JSON array with exercises testing past_tense:
# [
#   {"type": "fill_in_blank", "question": "[Italian sentence about buttons with ___ blank for past_tense]", "correct_answer": "[conjugated form in past_tense]", "options": null, "explanation": "[grammar rule explanation]"},
#   {"type": "translation", "question": "Translate: [English sentence about buttons in past_tense]", "correct_answer": "[Italian translation using past_tense]", "options": null, "explanation": "[grammar note]"},
#   {"type": "multiple_choice", "question": "[Italian sentence about buttons with blank]", "correct_answer": "[correct form in past_tense]", "options": ["[alt1]", "[alt2]", "[alt3]", "[alt4]"], "explanation": "[why this form is correct]"}
# ]
#
# NOW GENERATE 2 EXERCISES ABOUT "buttons" TESTING "past_tense" (remember: past_tense ONLY!):
# [<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
#
#
# 🔍 FULL RAW MODEL OUTPUT:
# system
#
# You are an expert Italian language teacher. Generate high-quality exercises based on the assignment specification. Output exercises in JSON format.user
#
# Create exactly 2 Italian language exercises (#1, #2) in JSON format about 'buttons' focusing on past_tense.
#
# REQUIREMENTS:
# Level: A1
# Topic: buttons
# Grammar: past_tense
# ⚠️ MANDATORY: Use ONLY past tense (passato prossimo like 'ho fatto','sono andato' OR imperfetto like 'facevo', 'andavo'). NO present tense!
# Exercise types: translation, fill_in_blank
#
# CRITICAL RULES:
# 1. TOPIC: Every exercise MUST be about "buttons" - stay on topic throughout
# 2. REALISM: Use factual, natural scenarios appropriate for the topic
# 3. GRAMMAR: EVERY SINGLE exercise MUST test "past_tense" at A1 level
# 4. MULTIPLE CHOICE: Provide 4 DIFFERENT grammatical forms as options
# 5. CONSISTENCY: Do not mix different topics or introduce unrelated subjects
#
# OUTPUT FORMAT - JSON array with exercises testing past_tense:
# [
#   {"type": "fill_in_blank", "question": "[Italian sentence about buttons with ___ blank for past_tense]", "correct_answer": "[conjugated form in past_tense]", "options": null, "explanation": "[grammar rule explanation]"},
#   {"type": "translation", "question": "Translate: [English sentence about buttons in past_tense]", "correct_answer": "[Italian translation using past_tense]", "options": null, "explanation": "[grammar note]"},
#   {"type": "multiple_choice", "question": "[Italian sentence about buttons with blank]", "correct_answer": "[correct form in past_tense]", "options": ["[alt1]", "[alt2]", "[alt3]", "[alt4]"], "explanation": "[why this form is correct]"}
# ]
#
# NOW GENERATE 2 EXERCISES ABOUT "buttons" TESTING "past_tense" (remember: past_tense ONLY!):
# [assistant
#
# [
#   {"type": "fill_in_blank", "question": "La mamma ha ___ (portare) le bottiglie al frigorifero.", "correct_answer": "portato", "options": null, "explanation": "Past tense for 'portare'." },
#   {"type": "fill_in_blank", "question": "Io ___ (premere) il pulsante per accendere la luce.", "correct_answer": "premesi", "options": null, "explanation": "Imperative past tense for 'premere'." }
# ]
# --------------------------------------------------
# ✅ CLEANED JSON BLOCK EXTRACTED:
# [
#   {"type": "fill_in_blank", "question": "La mamma ha ___ (portare) le bottiglie al frigorifero.", "correct_answer": "portato", "options": null, "explanation": "Past tense for 'portare'." },
#   {"type": "fill_in_blank", "question": "Io ___ (premere) il pulsante per accendere la luce.", "correct_answer": "premesi", "options": null, "explanation": "Imperative past tense for 'premere'." }
# ]
# --------------------------------------------------
# 🎯 SUCCESS: Parsed 2 exercises!
# --------------------------------------------------
#
# ============================================================
# 📝 Exercise 1 Score: 90.0/100
# ============================================================
# Type: fill_in_blank
# Question: La mamma ha ___ (portare) le bottiglie al frigorifero.
# Answer: portato
#
# Details: Score: 90.0/100
#   JSON: 15.0/15
#   Linguistic: 44.0/35
#   CEFR: 11.0/20
#   Fluency: 10.0/10
#   Grammar: 10.0/10
#   Topic: 0.0/10
# Errors: Sentences too long for A1 (avg: 14.0, expected: 3-10), Vocabulary may be too advanced for A1 (coverage: 50%), Similarity error: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
#
# ============================================================
# 📝 Exercise 2 Score: 76.0/100
# ============================================================
# Type: fill_in_blank
# Question: Io ___ (premere) il pulsante per accendere la luce.
# Answer: premesi
#
# Details: Score: 76.0/100
#   JSON: 15.0/15
#   Linguistic: 44.0/35
#   CEFR: 7.0/20
#   Fluency: 10.0/10
#   Grammar: 0.0/10
#   Topic: 0.0/10
# Errors: Sentences too long for A1 (avg: 14.0, expected: 3-10), Vocabulary too advanced for A1 (coverage: 25%), Expected past_tense, found tenses: [[], []], Similarity error: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %% [markdown]
# ## Test Generation
